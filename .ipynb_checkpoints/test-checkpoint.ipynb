# %%
import pandas as pd
import ipynbname

file1 = "D:\\DATA\\1050201New\\113校外實習書面審查作業\\0000_校庫資料_11210學10.學生實習人數及時數(10月填報).xlsx"

df1 = pd.read_excel(file1)

print(len(df1))
print(df1.columns)

df1.head()
# Out:
# 80
# Index(['代碼', '學校名稱', '學年度', '學院代碼', '學院', '單位代碼', '單位', '校區', '學制代碼', '學制班別',
#        '統計處科系所代碼', '年級', '實習屬性代碼', '實習屬性', '學分',
#        '是否屬專門職業技術人員(醫事人員、社會工作師)應考資格規定之實習', '實習場所國別代碼', '實習場所國別', '實習場所代碼',
#        '實習場所', '證明文件類型代碼', '證明文件類型', '實習時間代碼', '實習時間', '本國學生數_男', '本國學生數_女',
#        '本國學生數_總時數', '境外學生數_男', '境外學生數_女', '境外學生數_總時數', '補充說明'],
#       dtype='object')
#       代碼    學校名稱  學年度  學院代碼       學院  單位代碼         單位   校區 學制代碼 學制班別  ...  \
# 0  14523  國立高雄大學  111   126  人文社會科學院  6463  工藝與創意設計學系  校本部   u1  學士班  ...
# 1  14523  國立高雄大學  111   126  人文社會科學院  6463  工藝與創意設計學系  校本部   u1  學士班  ...
# 2  14523  國立高雄大學  111   126  人文社會科學院  6463  工藝與創意設計學系  校本部   u1  學士班  ...
# 3  14523  國立高雄大學  111   126  人文社會科學院  6463  工藝與創意設計學系  校本部   u1  學士班  ...
# 4  14523  國立高雄大學  111   126  人文社會科學院  6463  工藝與創意設計學系  校本部   u1  學士班  ...
#
#    證明文件類型  實習時間代碼  實習時間 本國學生數_男  本國學生數_女 本國學生數_總時數  境外學生數_男 境外學生數_女  \
# 0      合約       2  暑假實習     NaN      1.0     160.0      NaN     NaN
# ...

# %%
nb_fname = ipynbname.name()
print(nb_fname)
# Out:
# 130205_111學年實習課程書面審查作業

# %%
#jupyter nbconvert <path/to/notebook.ipynb>  --to <x> --output <"name" (without file extension)> --output-dir <path/to/new/file>


nb_fname = ipynbname.name()
print(nb_fname)

#c.NbConvertApp.notebooks = ["130205_111學年實習課程書面審查作業.ipynb"]

test = nb_fname + '.jpynb'
try:   
    # !jupyter nbconvert --to python $test
    #!jupyter nbconvert $test --to python --output 130205_111學年實習課程書面審查作業
    #!jupyter nbconvert --to python --output '{nb_fname}'
    #!jupyter nbconvert --to python nb_fname.ipynb
    # file_name.ipynb是当前模块的文件名
    # 转化完成后会生成file_name.py
except:
    pass
# Out:
# 130205_111學年實習課程書面審查作業
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
# ...

# %%
import ipynbname
nb_fname = ipynbname.name()
print(nb_fname)

# %%
# !jupyter nbconvert --help
# Out:
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
# ...
